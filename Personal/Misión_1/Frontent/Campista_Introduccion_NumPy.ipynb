# %% [markdown]
# # Introducción a NumPy

# %% [markdown]
# [Numpy](https://numpy.org) es una librería fundamental para la computación científica con Python.
# * Proporciona arrays N-dimensionales
# * Implementa funciones matemáticas sofisticadas
# * Proporciona mecanismos para facilitar la realización de tareas relacionadas con álgebra lineal o números aleatorios

# %% [markdown]
# ## Imports

# %%
import numpy as np

# %% [markdown]
# ## Arrays

# %% [markdown]
# Un **array** es una estructura de datos que consiste en una colección de elementos (valores o variables), cada uno identificado por al menos un índice o clave. Un array se almacena de modo que la posición de cada elemento se pueda calcular a partir de su tupla de índice mediante una fórmula matemática. El tipo más simple de array es un array lineal, también llamado array unidimensional.

# %% [markdown]
# En numpy:
# * Cada dimensión se denomina **axis**
# * El número de dimensiones se denomina **rank**
# * La lista de dimensiones con su correspondiente longitud se denomina **shape**
# * El número total de elementos (multiplicación de la longitud de las dimensiones) se denomina **size**

# %%
# Array cuyos valores son todo 0

# %% [markdown]
# _**a**_ es un array:
# * Con dos **axis**, el primero de longitud 2 y el segundo de longitud 4
# * Con un **rank** igual a 2
# * Con un **shape** igual (2, 4)
# * Con un **size** igual a 8

# %% [markdown]
# ## Creación de Arrays

# %%
# Array cuyos valores son todo 0

# %%
# Array cuyos valores son todo 1

# %%
#Array cuyos valores son todos   el valor indicado como segundo  parámetro

# %%
#El resultado de np.empty no es predecible
# inicializa los valores con lo que tenga en memoria

# %%
# inicialización del array utilizando un  array de python

# %%
#Creación del array utilizando una función basada en rangos
# minimo, maximo, número de elementos del array

# %%
#Inicializar el array con valores aleatorios

# %%
# valores aleatorios

# %%
# Inicialización del array utilizando una función personalizada

# %% [markdown]
# ## Acceso a los elementos de un array

# %% [markdown]
# ### Array unidimensional

# %%
#Creación de un Array Unidemensional

# %%
#Accediendo al tercer elemento del array

# %%
#Accediendo al tercer y cuarto elemento del array

# %%
#Acceder a los elementos en saltos de dos iniciando en la posición 2

# %% [markdown]
# ### Array multidimensional

# %%
#creación de un array multidimensional

# %%
#Accediendo al cuarto alemento del array

# %%
#Accediendo a la segunda fila

# %% [markdown]
# ## Modificación de un Array

# %%
#Creación de un  array unidimensional inicializado con el rango de elementos 0-10

# %%
#cambiar la dimensiones del array y su longitudes

# %%
#devolviendo el array a una sola dimensión ravel()

# %% [markdown]
# ## Operaciones aritméticas con Arrays

# %%
#creación de dos arrays unidimensionales

# %%
#suma

# %%
#resta

# %%
#multiplicar

# %% [markdown]
# ## Broadcasting

# %% [markdown]
# Si se aplican operaciones aritméticas sobre Arrays que no tienen la misma forma (shape) Numpy aplica un propiedad que se denomina Broadcasting.

# %%
#creación de dos arrays unidimensionales

# %%
#suma arreglos diferente tamaño

# %%
#creación de dos arrays multidimensional y unidimensional

# %% [markdown]
# Ejemplo 1: suma de un escalar a un arreglo (se quiere sumar un solo número acada elemento del arreglo

# %%
#crear arreglo de ejemplo

#sumar un escalar

# %% [markdown]
# Ejemplo 2: suma de un matriz que tiene 3x3 y quiere sumar un arreglo a una sola dimensión

# %%
#crear matriz 3x3


#crear arreglo de ejemplo

# %% [markdown]
# Ejemplo 3 Multiplicación de un arreglo a una matriz(broadcasting en una dimensión extra)
# queremos multiplicar cada elemento del arreglo por cada columna de la matriz

# %%
#crear matriz de 3x3

#crear arreglo de ejemplo

#multiplicación de la matriz y el arreglo

# %% [markdown]
# Ejercicio para practica

# %% [markdown]
# 1 Resta entre un arreglo y una matriz
# crea un arreglo  de una dimensión con valores [10,20,30], crea una matriz de tamaño 3x3 con valores secuenciales, resta el arreglo a cada fila de la matriz usando broadcasting

# %%
# crear un matriz secuencial de 3x3

# %% [markdown]
# 2 operaciones con matrices de diferente formas:
# crear una matriz  de 2x3 y otra de 3x1 utilizar broadcasting para sumar matriz a y matriz b

# %%
#crear matriz 2x3

#crear matriz 3x1

# %% [markdown]
# 3 División con broadcasting
# crear una matriz de 4x2 con valores secuenciales. Divide la matriz en un arreglo de 1D[2,4]

# %%
#crear matriz de 4x2

#crear arreglo de 1D

# %% [markdown]
# Contexto: análisis de datos meteorológicos
#
# Imaginemos que estás analizando datos meteorológicos de temperaturas en diferentes ciudades durante una semana. Los datos de temperaturas están en Celsius, pero necesitas convertirlos a fahrenheit para un informe internacional.
# Objetivo:
#
# usaremos broadcasting para:
#
# 1.	convertir una matriz de temperaturas en Celsius a Fahrenheit
#
# 2.	comparar las temperaturas promedio de cada día con el promedio semanal y calcular la desviación
#
#
# Datos
#
# tenemos una matriz de temperaturas (en grados Celsius) para 5 ciudades durante 7 días

# %% [markdown]
# Paso1: Comvertir celsius a fahrenheit usando Broadcasting
# Fórmula  fahrenheit= celsius x 1.8+32

# %% [markdown]
# Paso 2 Calcular el promedio semanal por ciudad
# para obtener una idea general de la temperatura media en cada ciudad durante la semana, calculamos el promedio de cada fila

# %%
#promedio semanal de temperatura en cada ciudad

#promedio días de temperatura

#promedio de todas las temperaturas

#Desviación diaria por ciudad en comparación con el promedio diario

# %% [markdown]
# ## Funciones estadísticas sobre Arrays

# %%
#creación de array unidimensional

#media de los elementos del array

# %% [markdown]
# Funciones universales eficientes proporcionadas por numpy: **ufunc**

# %%
#suma de elementos del array

# %%
#suma de elementos del array

# %%
#cuadrado de los elementos de un array

# %%
#raiz cuadarda de los elementos del array
